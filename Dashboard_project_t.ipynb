# %% [markdown]
# <a href="https://colab.research.google.com/github/Gcpppinpak/data_viz_2022/blob/main/Dashboard_project_t.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Covid-19

# %%
import pandas as pd
import os

# %%
from google.colab import drive      # ชี้ไฟล์ที่อยู่ใน google drive เพื่อเชื่อมต่อไฟล์
drive.mount('/content/drive')
path =  '/content/drive/My Drive/covid19_data'    # ชี้ dirve ที่เราต้องการ
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##ข้อมูล 12/1/2020 - 11/8/2021

# %%
data_file_path1 = os.path.join(path,'confirmed-cases.xlsx')   #ข้อมูล 12/1/2020 - 11/8/2021
data_covid1 = pd.read_excel(data_file_path1)   # อ่านไฟล์ excel

# %%
data1 = data_covid1

# %%
display(data_covid1.head(5),data_covid1.tail(5))
# Out:
#    No. announce_date Notified date   sex   age Unit nationality  \
# 0  1.0    2020-01-12           NaT  หญิง  61.0   ปี       China
# 1  2.0    2020-01-17           NaT  หญิง  74.0   ปี       China
# 2  3.0    2020-01-22           NaT  หญิง  73.0   ปี    Thailand
# 3  4.0    2020-01-22           NaT   ชาย  68.0   ปี       China
# 4  5.0    2020-01-24           NaT  หญิง  66.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset
# 0               NaN
# 1               NaN
# 2             เมือง
# 3               NaN
# ...

# %% [markdown]
# #### หาค่า missing

# %%
data_covid1.isnull() #ตรวจสอบว่ามีเซลล์ใดบ้างมีค่า NaN
# Out:
#           No.  announce_date  Notified date    sex    age   Unit  nationality  \
# 0       False          False           True  False  False  False        False
# 1       False          False           True  False  False  False        False
# 2       False          False           True  False  False  False        False
# 3       False          False           True  False  False  False        False
# 4       False          False           True  False  False  False        False
# ...       ...            ...            ...    ...    ...    ...          ...
# 816984  False          False          False  False  False  False        False
# 816985  False          False          False  False  False  False        False
# 816986  False          False          False  False  False  False        False
# 816987  False          False          False  False  False  False        False
# 816988  False          False          False  False  False  False        False
#
# ...

# %%
data_covid1.isnull().any() #ตรวจสอบว่ามีฟิลด์ใดบ้างที่มีค่าNaN
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_covid1.isnull().sum() #จำนวนค่าNaN ในแต่ละฟิลด์
# Out:
# No.                           0
# announce_date                 0
# Notified date              2795
# sex                       53005
# age                       74778
# Unit                      74637
# nationality               82076
# province_of_isolation       272
# risk                       1094
# province_of_onset         97112
# district_of_onset        155300
# dtype: int64

# %%
data1.index
# Out:
# RangeIndex(start=0, stop=816989, step=1)

# %%
data1.columns
# Out:
# Index(['No.', 'announce_date', 'Notified date', 'sex', 'age', 'Unit',
#        'nationality', 'province_of_isolation', 'risk', 'province_of_onset',
#        'district_of_onset'],
#       dtype='object')

# %% [markdown]
# ####ลบ column ข้อมูลที่ไม่ได้ใช้

# %%
data1.drop(['No.','Notified date','Unit','nationality','province_of_isolation'],axis=1, inplace = True)

# %%
data1
# Out:
#        announce_date   sex   age  \
# 0         2020-01-12  หญิง  61.0
# 1         2020-01-17  หญิง  74.0
# 2         2020-01-22  หญิง  73.0
# 3         2020-01-22   ชาย  68.0
# 4         2020-01-24  หญิง  66.0
# ...              ...   ...   ...
# 816984    2021-08-11  หญิง   8.0
# 816985    2021-08-11   ชาย  14.0
# 816986    2021-08-11   ชาย  59.0
# 816987    2021-08-11  หญิง  34.0
# 816988    2021-08-11  หญิง  19.0
#
#                                                      risk province_of_onset  \
# 0                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                                   ...               ...
# ...

# %% [markdown]
# ##ข้อมูล 12/8/2021 - 25/10/2021

# %%
data_file_path2 = os.path.join(path,'confirmed-cases-since-120864.xlsx')   #ข้อมูล 12/8/2021 - 25/10/2021
data_covid2 = pd.read_excel(data_file_path2)   # อ่านไฟล์ excel

# %% [markdown]
# ##ข้อมูล 26/8/2021 - 27/2/2022

# %%
data_file_path3 = os.path.join(path,'confirmed-cases-since-271064.xlsx')    #ข้อมูล 26/8/2021 - 27/2/2022
data_covid3 = pd.read_excel(data_file_path3)   # อ่านไฟล์ excel

# %% [markdown]
# ##ข้อมูล 28/2/2022 - 22/3/2022

# %%
data_file_path4 = os.path.join(path,'confirmed-cases-since-280265.xlsx')    #ข้อมูล 28/2/2022 - 22/3/2022
data_covid4 = pd.read_excel(data_file_path4)   # อ่านไฟล์ excel

# %% [markdown]
# # Data ภูมิภาค

# %% [markdown]
# #Data หน่วยงานที่เข้าร่วมโครงการ หมอพร้อม
