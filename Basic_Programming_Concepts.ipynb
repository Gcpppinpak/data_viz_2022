# %% [markdown]
# <a href="https://colab.research.google.com/github/Gcpppinpak/data_viz_2022/blob/main/Basic_Programming_Concepts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fucntions ($f(x)= y$)

# %% [markdown]
# ```python
# def function(input_x):
#     # do something with input_x to get output_y
#     return output_y
# ```

# %% [markdown]
# $f1(x)=X^2+75$

# %%
def function_f1(x):
  a = x**2
  y = a + 75
  return y
  
  print ('done!')

# %%
function_f1(3)
# Out:
# 84

# %% [markdown]
# function มีส่วนสำคัญทั้งหมด 4 ส่วน
#
# 1.บอก python ว่าเราจะเขียนฟังก์ชั่น ชื่ออะไร def function_name(): (ขาดไม่ได้)
#
# 2.กำหนดตัวแปรที่จะเป็น input Input (ขาดได้)
#
# 3.ส่วนประมวลผล do_something with Input to get Output (ขาดไม่ได้)
#
# 4.ส่วน output return Output(ขาดได้)

# %% [markdown]
# ###**ตัวอย่าง function ที่มีส่วนประกอบครบ**

# %%
def function_f1(x):
    a = x**2
    y = a + 75
    return y

# %% [markdown]
# **ตัวอย่าง function ที่ ไม่มี input**

# %%
def pi_v():
    y = 3.14159265359
    return y

# %%
piv = pi_v()
circle_area_r2 = piv*(2**2)
print(circle_area_r2)
# Out:
# 12.56637061436

# %% [markdown]
# **Function ไม่มี process ไม่ได้**

# %%
def function_a():
# Out:
#   File "<ipython-input-10-07a0750214a8>", line 1
#     def function_a():
#                      ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# **ตัวอย่าง Function ที่ไม่มี output**

# %%
def print_name_id(name,id):
    print(f'ชื่อ {name} รหัสประจำตัว {id}')

# %%
print_name_id('พรภูมินทร์','623021006-9')
# Out:
# ชื่อ พรภูมินทร์ รหัสประจำตัว 623021006-9

# %%
a = print_name_id('พรภูมินทร์','623021006-9')
# Out:
# ชื่อ พรภูมินทร์ รหัสประจำตัว 623021006-9

# %% [markdown]
# ตัวอย่าง function `print` https://www.programiz.com/python-programming/methods/built-in/print

# %% [markdown]
# ![2022-01-05.png](data:image/png;base64,...)

# %%
print('พรภูมินทร์')
print('623021006-9')
# Out:
# พรภูมินทร์
# 623021006-9

# %%
print('พรภูมินทร์',end='->' )
print('623021006-9')
# Out:
# พรภูมินทร์->623021006-9

# %%
print('พรภูมินทร์','623021006-9')
# Out:
# พรภูมินทร์ 623021006-9

# %%
print('พรภูมินทร์','623021006-9',sep=' & ')
# Out:
# พรภูมินทร์ & 623021006-9

# %% [markdown]
# **input ของ function แบ่งเป็น 2 ชนิด (จำเป็นต้องใส่ กับ ไม่จำเป็นต้องใส่)**
#
# ตัวอย่าง function print_grade() มี input 3 ตัว จำเป็นต้องใส่ 2 ตัว คือ name กับ id และไม่จำเป็นต้องใส่ 1 ตัว คือเกรด ซึ่งมีค่า default เป็น F

# %%
def print_grade(name,id,grade = 'F'):
    print(f'รหัสประจำตัว {id} ชื่อ {name}')
    print(f'ได้เกรด {grade}')

# %%
print_grade('นายสิทธัตกะ จรัสแสง','623020541-2')
# Out:
# รหัสประจำตัว 623020541-2 ชื่อ นายสิทธัตกะ จรัสแสง
# ได้เกรด F

# %%
print_grade('นายสิทธัตกะ จรัสแสง','623020541-2','A')
# Out:
# รหัสประจำตัว 623020541-2 ชื่อ นายสิทธัตกะ จรัสแสง
# ได้เกรด A

# %%
print_grade(id='623020541-2',name='นายสิทธัตกะ จรัสแสง',grade='B+')
# Out:
# รหัสประจำตัว 623020541-2 ชื่อ นายสิทธัตกะ จรัสแสง
# ได้เกรด B+

# %% [markdown]
# ###Looping (for)

# %% [markdown]
# ```python
# for member in listEx:
#     do_something()
# ```

# %%
for member in [1,2,3,4,5,6]:
  print(member)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
def print_name(name):
  print(f'ฉันชื่อ {name}')

# %%
for name in ['พรภูมินทร์','พรภูมินทร์','พรภูมินทร์','พรภูมินทร์','พรภูมินทร์']:
  N = name
  print_name(N)
# Out:
# ฉันชื่อ พรภูมินทร์
# ฉันชื่อ พรภูมินทร์
# ฉันชื่อ พรภูมินทร์
# ฉันชื่อ พรภูมินทร์
# ฉันชื่อ พรภูมินทร์

# %%
list_name_id_grade = [['นางสาวพรภูมินทร์ ประเสริฐ','623021006-9','A'],
                        ['นางสาวพรภูมินทร์ ประเสริฐ','623021006-9','A'],['นางสาวพรภูมินทร์ ประเสริฐ','623021006-9','A']]

# %%
for each in list_name_id_grade:
  name = each[0]
  id = each[1]
  grade = each[2]
  print_grade(name,id,grade)
  print('-----------------')
# Out:
# รหัสประจำตัว 623021006-9 ชื่อ นางสาวพรภูมินทร์ ประเสริฐ
# ได้เกรด A
# -----------------
# รหัสประจำตัว 623021006-9 ชื่อ นางสาวพรภูมินทร์ ประเสริฐ
# ได้เกรด A
# -----------------
# รหัสประจำตัว 623021006-9 ชื่อ นางสาวพรภูมินทร์ ประเสริฐ
# ได้เกรด A
# -----------------

# %% [markdown]
# ###ใช้ Loop เพิ่ทสมาชิกใน list

# %%
list_name = []
list_id = []
list_grade = []
for each in list_name_id_grade:
    list_name.append(each[0])
    list_id.append(each[1])
    list_grade.append(each[2])

# %%
list_name
# Out:
# ['นางสาวพรภูมินทร์ ประเสริฐ',
#  'นางสาวพรภูมินทร์ ประเสริฐ',
#  'นางสาวพรภูมินทร์ ประเสริฐ']
